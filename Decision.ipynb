# %% [markdown]
# If else statement

# %%
#Please enter the activity to be performed.

print("Please enter the activity to be performed.")
activity = input() 

# Determine if the activity is calculate
if activity == "calculate":
    print("Performing calculations...")
else:
    print("Performing activity...")

print("Activity completed.")
# Out:
# Please enter the activity to be performed.
# Performing activity...
# Activity completed.

# %% [markdown]
# if_elif_else statement

# %%
# Ask user for the direction 
print("Towards which direction should I paint (up, down, left or right)?")
direction = input() 

# Determine which message to display
if direction == "up":
    print("I am painting in the upward direction!")
elif direction == "down":
    print("I am painting in the downward direction!")
elif direction == "left":
    print("I am painting in the leftward direction!")
elif direction == "right":
    print("I am painting in the rightward direction!")
else:
    print("Not sure which direction in am painting in!")
# Out:
# Towards which direction should I paint (up, down, left or right)?
# I am painting in the upward direction!

# %% [markdown]
# [modulo_operator]

# %%
# Ask user for a number 
print("Please enter a whole number.")
number = int(input()) 

# Display relevant message
if number % 2 == 0:
    print(f"The number {number} is an even number.")
else:
    print(f"The number {number} is an odd number.")
# Out:
# Please enter a whole number.
# The number 3 is an odd number.

# %% [markdown]
# [comparison_operators]

# %%
# Ask user for the direction 
print("Please enter the first number.")
first_number = int(input()) 

print("Please enter the second number.")
second_number = int(input())

# Determine which message to display
if first_number < second_number:
    print("The first number is the smallest.")
elif first_number > second_number:
    print("The second number is the smallest.")
else:
    print("The two numbers are equal.")
# Out:
# Please enter the first number.
# Please enter the second number.
# The first number is the smallest.

# %% [markdown]
# Self_Defiend Problem - Selection Control

# %%
# 1. Get Input
age = int(input("Enter age: "))
caffeine = float(input("Enter caffeine intake (mg): "))

# 2. Check Logic & Set Limits
if age < 18:
    print("Classification: Child/Teen")
    limit = 100
else:
    print("Classification: Adult")
    limit = 400

# 3. Check Safety Condition
if caffeine > limit:
    print("Status: Warning: Exceeds recommended daily caffeine intake")
else:
    print("Status: Safe daily intake")
# Out:
# Classification: Adult
# Status: Safe daily intake
